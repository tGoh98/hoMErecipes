# %%
import requests
import pandas as pd
from functools import *
import numpy as np
import nltk
# %load_ext autoreload
# %autoreload 2
import recip as rr
import dill
import submatcher as sm
import hashlib

# %%
inp = ["flour","butter","milk", "egg", "cheese"]

# %%
allr = rr.GetRecipies(inp, recnum = 10)
# Out:
# Recipe cache found
# recipe Fluffy Mozzarella Biscuits cache found
# recipe Cheese Muffins cache found
# recipe Cabrales Cheese Souffles with Endive and Asian Pear Salad cache found
# recipe Berry sweet empanadas cache found
# recipe Ocean-themed Vanilla Cupcakes for Broadway’s "Anything Goes cache found
# recipe Cheesy Popovers cache found
# recipe Fancy French Cheese Puff Fake-out cache found
# recipe Parmesan Puffs cache found
# recipe Cheese Puffs cache found
# recipe Parmesan Herb Popovers Recipe cache found

# %%
allr.to_json()
# Out:
# {'Fluffy Mozzarella Biscuits': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 559259,
#   'imglink': 'https://spoonacular.com/recipeImages/559259-312x231.jpg',
#   'missedCount': 3,
#   'missedIngs': ['2 tbsp baking powder',
#    '2 tsp salt',
#    '2 cups shredded mozzarella cheese'],
#   'name': 'Fluffy Mozzarella Biscuits',
#   'price': 34.01,
#   'serving': 18,
#   'subIngs': {'baking powder': {'baking powder': ['1/4 teaspoon baking soda plus 1/2 teaspoon cream of tartar ',
#      ' 1/4 teaspoon baking soda plus 1/2 cup buttermilk (decrease liquid in recipe by 1/2 cup)']},
#    'shredded mozzarella cheese': {'cheddar cheese': ['1 cup shredded Colby cheddar ',
#      '1 cup shredded Monterey Jack cheese'],
#     'cottage cheese': ["1 cup farmer's cheese ", '1 cup ricotta cheese'],
#     'cream cheese': ['1 cup pureed cottage cheese ',
#      '1 cup plain yogurt, strained overnight in a cheesecloth'],
#     "farmer's cheese": ['8 ounces dry cottage cheese ',
#      '8 ounces creamed cottage cheese, drained'],
#     'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese']}},
#   'urls': {'source': 'http://www.jocooks.com/bakery/breads/fluffy-mozzarella-biscuits/',
#    'img': 'https://spoonacular.com/recipeImages/559259-556x370.jpg'},
#   'usedCount': 4,
#   'usedIngs': ['3 1/2 cups all purpose flour',
#    '9 tbsp cold butter, cut in cubes (1 stick plus 1 tbsp)',
#    '1 egg, for egg wash',
#    '1 3/4 cups milk, cold']},
#  'Cheese Muffins': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 65540,
#   'imglink': 'https://spoonacular.com/recipeImages/65540-312x231.jpg',
#   'missedCount': 4,
#   'missedIngs': ['1 tbsp Baking Powder',
#    '3 cup Colby Jack Cheese, Shredded',
#    '1/2 tsp Salt',
#    '1 1/2 tbsp Sugar'],
#   'name': 'Cheese Muffins',
#   'price': 167.31,
#   'serving': 4,
#   'subIngs': {'baking powder': {'baking powder': ['1/4 teaspoon baking soda plus 1/2 teaspoon cream of tartar ',
#      ' 1/4 teaspoon baking soda plus 1/2 cup buttermilk (decrease liquid in recipe by 1/2 cup)']},
#    'colby jack cheese': {'cheddar cheese': ['1 cup shredded Colby cheddar ',
#      '1 cup shredded Monterey Jack cheese'],
#     'cottage cheese': ["1 cup farmer's cheese ", '1 cup ricotta cheese'],
#     'cream cheese': ['1 cup pureed cottage cheese ',
#      '1 cup plain yogurt, strained overnight in a cheesecloth'],
#     "farmer's cheese": ['8 ounces dry cottage cheese ',
#      '8 ounces creamed cottage cheese, drained'],
#     'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese']},
#    'sugar': {'brown sugar': ['1 cup white sugar plus 1/4 cup molasses and decrease the liquid in recipe by 1/4 cup ',
#      '1 cup white sugar',
#      "1 1/4 cups confectioners' sugar"],
#     'white sugar': ['1 cup brown sugar ',
#      "1 1/4 cups confectioners' sugar",
#      '3/4 cup honey',
#      '3/4 cup corn syrup']}},
#   'urls': {'source': 'http://thepioneerwoman.com/cooking/2008/08/dairy-contest-finalist-recipe-cheese-muffins/',
#    'img': 'https://spoonacular.com/recipeImages/65540-556x370.jpg'},
#   'usedCount': 4,
#   'usedIngs': ['1/4 cup Melted Butter, 1/2 stick',
#    '1 x Egg',
#    '1 1/2 cup Flour',
#    '1 cup Milk']},
#  'Cabrales Cheese Souffles with Endive and Asian Pear Salad': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': ['Indian', 'Asian'],
#   'id': 14438,
#   'imglink': 'https://spoonacular.com/recipeImages/14438-312x231.jpg',
#   'missedCount': 4,
#   'missedIngs': ['Endive and Asian Pear Salad',
#    '1/4 teaspoon coarse kosher salt',
#    '1/2 teaspoon coarsely ground black pepper',
#    '2 tablespoons (1/4 stick) unsalted butter'],
#   'name': 'Cabrales Cheese Souffles with Endive and Asian Pear Salad',
#   'price': 41.9,
#   'serving': 6,
#   'subIngs': {'ground pepper': {'hot pepper sauce': ['3/4 teaspoon cayenne pepper plus 1 teaspoon vinegar']},
#    'unsalted butter': {'butter (salted)': ['1 cup margarine ',
#      ' 1 cup shortening plus 1/2 teaspoon salt ',
#      ' 7/8 cup vegetable oil plus 1/2 teaspoon salt ',
#      ' 7/8 cup lard plus 1/2 teaspoon salt'],
#     'butter (unsalted)': ['1 cup shortening ',
#      ' 7/8 cup vegetable oil ',
#      ' 7/8 cup lard']}},
#   'urls': {'source': 'http://www.epicurious.com/recipes/food/views/Cabrales-Cheese-Souffles-with-Endive-and-Asian-Pear-Salad-109055',
#    'img': 'https://spoonacular.com/recipeImages/14438-556x370.jpg'},
#   'usedCount': 4,
#   'usedIngs': ['1/4 cup all purpose flour',
#    '6 ounces Cabrales or Maytag blue cheese, crumbled (about 3/4 cup packed)',
#    '3 large eggs, separated',
#    '1 cup whole milk']},
#  'Berry sweet empanadas': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': ['Eastern European', 'Spanish', 'European'],
#   'id': 547622,
#   'imglink': 'https://spoonacular.com/recipeImages/547622-312x231.jpg',
#   'missedCount': 5,
#   'missedIngs': ['14-16 blackberries or raspberries',
#    '- 1 1/4 cup Sargento part-skim ricotta cheese',
#    'pinch of salt',
#    '2 tbsp sugar',
#    'iced cold water'],
#   'name': 'Berry sweet empanadas',
#   'price': 23.99,
#   'serving': 14,
#   'subIngs': {'part skim ricotta cheese': {'cheddar cheese': ['1 cup shredded Colby cheddar ',
#      '1 cup shredded Monterey Jack cheese'],
#     'cottage cheese': ["1 cup farmer's cheese ", '1 cup ricotta cheese'],
#     'cream cheese': ['1 cup pureed cottage cheese ',
#      '1 cup plain yogurt, strained overnight in a cheesecloth'],
#     "farmer's cheese": ['8 ounces dry cottage cheese ',
#      '8 ounces creamed cottage cheese, drained'],
#     'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese'],
#     'ricotta': ['1 cup dry cottage cheese ', '1 cup silken tofu']},
#    'sugar': {'brown sugar': ['1 cup white sugar plus 1/4 cup molasses and decrease the liquid in recipe by 1/4 cup ',
#      '1 cup white sugar',
#      "1 1/4 cups confectioners' sugar"],
#     'white sugar': ['1 cup brown sugar ',
#      "1 1/4 cups confectioners' sugar",
#      '3/4 cup honey',
#      '3/4 cup corn syrup']}},
#   'urls': {'source': 'http://roxanashomebaking.com/berry-sweet-empanadas-recipe/',
#    'img': 'https://spoonacular.com/recipeImages/547622-556x370.jpg'},
#   'usedCount': 4,
#   'usedIngs': ['2 1/2 cups (300 grams) all purpose flour',
#    '1/2 cup (113 grams) diced cold butter',
#    '1 egg yolked',
#    '- 2 tbsp milk to brush the unbaked empanadas']},
#  'Ocean-themed Vanilla Cupcakes for Broadway’s "Anything Goes': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': ['American'],
#   'id': 571447,
#   'imglink': 'https://spoonacular.com/recipeImages/571447-312x231.jpg',
#   'missedCount': 5,
#   'missedIngs': ['6 oz Cream Cheese',
#    '2-4 cups powdered sugar',
#    '1 1/2 cups self-rising flour',
#    '2 cups sugar',
#    '1 tsp Vanilla Extract'],
#   'name': 'Ocean-themed Vanilla Cupcakes for Broadway’s "Anything Goes',
#   'price': 28.73,
#   'serving': 24,
#   'subIngs': {'cream cheese': {'cream cheese': ['1 cup pureed cottage cheese ',
#      '1 cup plain yogurt, strained overnight in a cheesecloth']},
#    'powdered sugar': {'brown sugar': ['1 cup white sugar plus 1/4 cup molasses and decrease the liquid in recipe by 1/4 cup ',
#      '1 cup white sugar',
#      "1 1/4 cups confectioners' sugar"],
#     'white sugar': ['1 cup brown sugar ',
#      "1 1/4 cups confectioners' sugar",
#      '3/4 cup honey',
#      '3/4 cup corn syrup']},
#    'self-rising flour': {'flour  bread': ['1 cup all-purpose flour plus 1 teaspoon wheat gluten (available at health food stores & some supermarkets)'],
#     'flour  cake': ['1 cup all-purpose flour minus 2 tablespoons'],
#     'flour  self rising': ['7/8 cup all-purpose flour plus 1 1/2 teaspoons baking powder and 1/2 teaspoon of salt']},
#    'sugar': {'brown sugar': ['1 cup white sugar plus 1/4 cup molasses and decrease the liquid in recipe by 1/4 cup ',
#      '1 cup white sugar',
#      "1 1/4 cups confectioners' sugar"],
#     'white sugar': ['1 cup brown sugar ',
#      "1 1/4 cups confectioners' sugar",
#      '3/4 cup honey',
#      '3/4 cup corn syrup']}},
#   'urls': {'source': 'http://www.the-baker-chick.com/2011/04/ocean-themed-vanilla-cupcakes-for-broadways-anything-goes/',
#    'img': 'https://spoonacular.com/recipeImages/571447-556x370.jpg'},
#   'usedCount': 4,
#   'usedIngs': ['1 1/2 stick Butter',
#    '4 large eggs, at room temperature',
#    '1 1/4 cups all-purpose flour',
#    '1 cup milk']},
#  'Cheesy Popovers': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 543391,
#   'imglink': 'https://spoonacular.com/recipeImages/543391-312x231.jpg',
#   'missedCount': 3,
#   'missedIngs': ['1/2 cup parmesan cheese, grated',
#    '1/2 teaspoon salt',
#    '2 tablespoons unsalted butter, melted'],
#   'name': 'Cheesy Popovers',
#   'price': 35.77,
#   'serving': 9,
#   'subIngs': {'parmesan cheese': {'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese']},
#    'unsalted butter': {'butter (salted)': ['1 cup margarine ',
#      ' 1 cup shortening plus 1/2 teaspoon salt ',
#      ' 7/8 cup vegetable oil plus 1/2 teaspoon salt ',
#      ' 7/8 cup lard plus 1/2 teaspoon salt'],
#     'butter (unsalted)': ['1 cup shortening ',
#      ' 7/8 cup vegetable oil ',
#      ' 7/8 cup lard']}},
#   'urls': {'source': 'http://weelicious.com/2011/12/19/cheesy-popovers/',
#    'img': 'https://spoonacular.com/recipeImages/543391-556x370.jpg'},
#   'usedCount': 3,
#   'usedIngs': ['2 cups all purpose flour', '3 large eggs', '2 cups milk']},
#  'Fancy French Cheese Puff Fake-out': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': ['Mediterranean',
#    'French',
#    'Eastern European',
#    'European',
#    'Greek'],
#   'id': 64248,
#   'imglink': 'https://spoonacular.com/recipeImages/64248-312x231.jpg',
#   'missedCount': 4,
#   'missedIngs': ['2 tsps fresh thyme',
#    'Salt and ground black pepper',
#    '1 cup grated Parmigiano Reggiano cheese',
#    '2 Tbsps unsalted butter, melted, divided'],
#   'name': 'Fancy French Cheese Puff Fake-out',
#   'price': 94.77,
#   'serving': 4,
#   'subIngs': {'fresh thyme': {'ginger  fresh': ['1/2 teaspoon ground dried ginger'],
#     'herbs  fresh': ['1 teaspoon (chopped or whole leaf) dried herbs'],
#     'mint  fresh': ['1 tablespoon dried mint leaves']},
#    'ground pepper': {'hot pepper sauce': ['3/4 teaspoon cayenne pepper plus 1 teaspoon vinegar']},
#    'parmigiano reggiano cheese': {'cheddar cheese': ['1 cup shredded Colby cheddar ',
#      '1 cup shredded Monterey Jack cheese'],
#     'cottage cheese': ["1 cup farmer's cheese ", '1 cup ricotta cheese'],
#     'cream cheese': ['1 cup pureed cottage cheese ',
#      '1 cup plain yogurt, strained overnight in a cheesecloth'],
#     "farmer's cheese": ['8 ounces dry cottage cheese ',
#      '8 ounces creamed cottage cheese, drained'],
#     'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese']},
#    'unsalted butter': {'butter (salted)': ['1 cup margarine ',
#      ' 1 cup shortening plus 1/2 teaspoon salt ',
#      ' 7/8 cup vegetable oil plus 1/2 teaspoon salt ',
#      ' 7/8 cup lard plus 1/2 teaspoon salt'],
#     'butter (unsalted)': ['1 cup shortening ',
#      ' 7/8 cup vegetable oil ',
#      ' 7/8 cup lard']}},
#   'urls': {'source': 'http://www.rachaelray.com/recipe.php?recipe_id=2230',
#    'img': 'https://spoonacular.com/recipeImages/64248-556x370.jpg'},
#   'usedCount': 3,
#   'usedIngs': ['3 eggs', '1 cup flour', '1 cup milk']},
#  'Parmesan Puffs': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 1105306,
#   'imglink': 'https://spoonacular.com/recipeImages/1105306-312x231.jpg',
#   'missedCount': 5,
#   'missedIngs': ['1/4 cup water',
#    '1/4 cup unsalted butter',
#    '1/4 tsp salt',
#    '1 cup fresh grated parmesan',
#    '1/4 tsp black pepper, preferably fresh cracked'],
#   'name': 'Parmesan Puffs',
#   'price': 42.43,
#   'serving': 8,
#   'subIngs': {'unsalted butter': {'butter (salted)': ['1 cup margarine ',
#      ' 1 cup shortening plus 1/2 teaspoon salt ',
#      ' 7/8 cup vegetable oil plus 1/2 teaspoon salt ',
#      ' 7/8 cup lard plus 1/2 teaspoon salt'],
#     'butter (unsalted)': ['1 cup shortening ',
#      ' 7/8 cup vegetable oil ',
#      ' 7/8 cup lard']},
#    'parmesan': {'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese']},
#    'black pepper': {'hot pepper sauce': ['3/4 teaspoon cayenne pepper plus 1 teaspoon vinegar']}},
#   'urls': {'source': 'https://lisasdinnertimedish.com/parmesan-popovers/',
#    'img': 'https://spoonacular.com/recipeImages/1105306-556x370.jpg'},
#   'usedCount': 3,
#   'usedIngs': ['1/4 cup milk', '1/2 cup flour', '2 large eggs']},
#  'Cheese Puffs': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 544640,
#   'imglink': 'https://spoonacular.com/recipeImages/544640-312x231.jpg',
#   'missedCount': 5,
#   'missedIngs': ['1/4 cup parmesan',
#    '1/2 teaspoon salt',
#    '1/2 cup cheddar cheese or gruyere, shredded',
#    '1/2 cup unsalted butter',
#    '1 teaspoon water'],
#   'name': 'Cheese Puffs',
#   'price': 14.87,
#   'serving': 30,
#   'subIngs': {'parmesan': {'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese']},
#    'shredded cheddar cheese': {'cheddar cheese': ['1 cup shredded Colby cheddar ',
#      '1 cup shredded Monterey Jack cheese']},
#    'unsalted butter': {'butter (salted)': ['1 cup margarine ',
#      ' 1 cup shortening plus 1/2 teaspoon salt ',
#      ' 7/8 cup vegetable oil plus 1/2 teaspoon salt ',
#      ' 7/8 cup lard plus 1/2 teaspoon salt'],
#     'butter (unsalted)': ['1 cup shortening ',
#      ' 7/8 cup vegetable oil ',
#      ' 7/8 cup lard']}},
#   'urls': {'source': 'http://weelicious.com/2010/02/23/1118/',
#    'img': 'https://spoonacular.com/recipeImages/544640-556x370.jpg'},
#   'usedCount': 3,
#   'usedIngs': ['1 cup all purpose flour', '6 large eggs', '1 cup milk']},
#  'Parmesan Herb Popovers Recipe': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 46953,
#   'imglink': 'https://spoonacular.com/recipeImages/46953-312x231.jpg',
#   'missedCount': 5,
#   'missedIngs': ['2 tsps finely chopped herbs: rosemary, thyme or sage (preferably fresh, but dried will also work)',
#    '1/2 cup freshly grated parmesan cheese',
#    '1/4 tsp salt',
#    '1 cup (5 ozs) unbleached, all purpose flour',
#    '2 Tbsps (1 oz) unsalted butter, melted'],
#   'name': 'Parmesan Herb Popovers Recipe',
#   'price': 127.38,
#   'serving': 2,
#   'subIngs': {'herbs': {'herbs  fresh': ['1 teaspoon (chopped or whole leaf) dried herbs']},
#    'parmesan cheese': {'parmesan cheese': ['1/2 cup grated Asiago cheese ',
#      '1/2 cup grated Romano cheese']},
#    'unbleached flour': {'flour  bread': ['1 cup all-purpose flour plus 1 teaspoon wheat gluten (available at health food stores & some supermarkets)'],
#     'flour  cake': ['1 cup all-purpose flour minus 2 tablespoons'],
#     'flour  self rising': ['7/8 cup all-purpose flour plus 1 1/2 teaspoons baking powder and 1/2 teaspoon of salt']},
#    'unsalted butter': {'butter (salted)': ['1 cup margarine ',
#      ' 1 cup shortening plus 1/2 teaspoon salt ',
#      ' 7/8 cup vegetable oil plus 1/2 teaspoon salt ',
#      ' 7/8 cup lard plus 1/2 teaspoon salt'],
#     'butter (unsalted)': ['1 cup shortening ',
#      ' 7/8 cup vegetable oil ',
#      ' 7/8 cup lard']}},
#   'urls': {'source': 'http://whiteonricecouple.com/recipes/baked-goods-savory/parmesan-herb-popovers/',
#    'img': 'https://spoonacular.com/recipeImages/46953-556x370.jpg'},
#   'usedCount': 2,
#   'usedIngs': ['2 large eggs', '1 cup (8 oz) whole milk']}}

# %%
import json
with open('testout.json', 'w', encoding='utf-8') as f:
    json.dump(allr.to_json(), f)

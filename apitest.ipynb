# %%
import requests
import pandas as pd
from functools import *
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
from backend import recip as rr

# %%
inp = ['baking soda', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar', 'vanilla extract']

# %%
allr = rr.GetRecipies(inp, recnum = 9)
# Out:
# Recipe cache found
# CACHE FOUND - Chocolate Pancakes and Friday Faves
# CACHE FOUND - Snickerdoodle Cream Pies
# CACHE FOUND - Soft & Chewy Peanut Butter Cookies
# CACHE FOUND - Chocolate Greek Yogurt Cupcakes
# CACHE FOUND - Peanut Butter Sheet Cake
# CACHE FOUND - Peanut Butter Blossoms
# CACHE FOUND - Vanilla Cupcakes with Vanilla Buttercream
# CACHE FOUND - Nutella Filled Peanut Butter Criss Crosses
# CACHE FOUND - Chocolate Biscoff Whoopie Pies

# %%
allr.to_json()
# Out:
# {'Chocolate Pancakes and Friday Faves': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 532566,
#   'imglink': 'https://spoonacular.com/recipeImages/532566-312x231.jpg',
#   'missedCount': 1,
#   'missedIngs': ['baking powder'],
#   'name': 'Chocolate Pancakes and Friday Faves',
#   'price': 71.6,
#   'serving': 8,
#   'subIngs': {'baking powder': {'baking powder': ['baking soda plus cream of tartar ',
#      ' baking soda plus buttermilk (decrease liquid in recipe by ']}},
#   'urls': {'source': 'http://www.foodiecrush.com/2013/02/chocolate-pancakes-and-friday-faves/',
#    'img': 'https://spoonacular.com/recipeImages/532566-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda', 'butter', 'egg', 'milk', 'vanilla']},
#  'Snickerdoodle Cream Pies': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 532528,
#   'imglink': 'https://spoonacular.com/recipeImages/532528-312x231.jpg',
#   'missedCount': 1,
#   'missedIngs': ['cinnamon'],
#   'name': 'Snickerdoodle Cream Pies',
#   'price': 17.53,
#   'serving': 12,
#   'subIngs': {},
#   'urls': {'source': 'http://premeditatedleftovers.com/saving-in-nevada/snickerdoodle-cream-pies/',
#    'img': 'https://spoonacular.com/recipeImages/532528-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda', 'butter', 'egg', 'milk', 'vanilla']},
#  'Soft & Chewy Peanut Butter Cookies': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 530372,
#   'imglink': 'https://spoonacular.com/recipeImages/530372-312x231.jpg',
#   'missedCount': 2,
#   'missedIngs': ['baking powder', 'peanut butter'],
#   'name': 'Soft & Chewy Peanut Butter Cookies',
#   'price': 6.76,
#   'serving': 48,
#   'subIngs': {'baking powder': {'baking powder': ['baking soda plus cream of tartar ',
#      ' baking soda plus buttermilk (decrease liquid in recipe by ']},
#    'peanut butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://www.everydayhomecook.com/2011/08/soft-chewy-peanut-butter-cookies/',
#    'img': 'https://spoonacular.com/recipeImages/530372-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda', 'butter', 'egg', 'milk', 'vanilla extract']},
#  'Chocolate Greek Yogurt Cupcakes': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': ['American'],
#   'id': 532935,
#   'imglink': 'https://spoonacular.com/recipeImages/532935-312x231.jpg',
#   'missedCount': 2,
#   'missedIngs': ['buttermilk', 'cocoa powder'],
#   'name': 'Chocolate Greek Yogurt Cupcakes',
#   'price': 19.92,
#   'serving': 20,
#   'subIngs': {'buttermilk': {'buttermilk': ['yogurt ',
#      ' lemon juice or vinegar plus milk ']},
#    'cocoa powder': {'baking powder': ['baking soda plus cream of tartar ',
#      ' baking soda plus buttermilk (decrease liquid in recipe by '],
#     'cocoa': ['square unsweetened chocolate']}},
#   'urls': {'source': 'http://www.lifeasastrawberry.com/chocolate-greek-yogurt-cupcakes/',
#    'img': 'https://spoonacular.com/recipeImages/532935-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda', 'butter', 'egg', 'milk', 'vanilla extract']},
#  'Peanut Butter Sheet Cake': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 530504,
#   'imglink': 'https://spoonacular.com/recipeImages/530504-312x231.jpg',
#   'missedCount': 2,
#   'missedIngs': ['buttermilk', 'peanut butter'],
#   'name': 'Peanut Butter Sheet Cake',
#   'price': 19.31,
#   'serving': 30,
#   'subIngs': {'buttermilk': {'buttermilk': ['yogurt ',
#      ' lemon juice or vinegar plus milk ']},
#    'peanut butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://www.everydayhomecook.com/2012/05/peanut-butter-sheet-cake/',
#    'img': 'https://spoonacular.com/recipeImages/530504-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda', 'butter', 'eggs', 'milk', 'vanilla']},
#  'Peanut Butter Blossoms': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 1056712,
#   'imglink': 'https://spoonacular.com/recipeImages/1056712-312x231.jpg',
#   'missedCount': 2,
#   'missedIngs': ['hershey kisses', 'smooth peanut butter'],
#   'name': 'Peanut Butter Blossoms',
#   'price': 11.26,
#   'serving': 48,
#   'subIngs': {'smooth peanut butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'https://addapinch.com/peanut-butter-blossoms-recipe/',
#    'img': 'https://spoonacular.com/recipeImages/1056712-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda', 'butter', 'egg', 'milk', 'vanilla extract']},
#  'Vanilla Cupcakes with Vanilla Buttercream': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': ['American'],
#   'id': 530620,
#   'imglink': 'https://spoonacular.com/recipeImages/530620-312x231.jpg',
#   'missedCount': 3,
#   'missedIngs': ['baking powder', 'egg whites', 'unsalted butter'],
#   'name': 'Vanilla Cupcakes with Vanilla Buttercream',
#   'price': 45.21,
#   'serving': 24,
#   'subIngs': {'baking powder': {'baking powder': ['baking soda plus cream of tartar ',
#      ' baking soda plus buttermilk (decrease liquid in recipe by ']},
#    'egg whites': {'egg': ['powdered egg substitute plus water ',
#      'liquid egg substitute',
#      'silken tofu pureed ',
#      ' mayonnaise',
#      'half a banana mashed with baking powder',
#      'powdered flax seed soaked in water']},
#    'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://www.thelittlekitchen.net/birthday-vanilla-cupcakes/',
#    'img': 'https://spoonacular.com/recipeImages/530620-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda',
#    'eggs',
#    'vanilla',
#    'vanilla extract',
#    'whole milk']},
#  'Nutella Filled Peanut Butter Criss Crosses': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 527267,
#   'imglink': 'https://spoonacular.com/recipeImages/527267-312x231.jpg',
#   'missedCount': 4,
#   'missedIngs': ['chocolate hazelnut spread',
#    'creamy peanut butter',
#    'creamy peanut butter',
#    'unsalted butter'],
#   'name': 'Nutella Filled Peanut Butter Criss Crosses',
#   'price': 191.13,
#   'serving': 3,
#   'subIngs': {'chocolate hazelnut spread': {'chocolate (unsweetened)': ['unsweetened cocoa plus shortening or vegetable oil'],
#     'semisweet chocolate chips': ['chocolate candies ',
#      'peanut butter or other flavored chips',
#      'chopped nuts',
#      'chopped dried fruit']},
#    'creamy peanut butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']},
#    'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://amandascookin.com/2012/12/nutella-filled-peanut-butter-criss-crosses.html',
#    'img': 'https://spoonacular.com/recipeImages/527267-556x370.jpg'},
#   'usedCount': 4,
#   'usedIngs': ['baking soda', 'egg', 'milk', 'vanilla']},
#  'Chocolate Biscoff Whoopie Pies': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 527691,
#   'imglink': 'https://spoonacular.com/recipeImages/527691-312x231.jpg',
#   'missedCount': 4,
#   'missedIngs': ['Biscoff spread',
#    'cream cheese block',
#    'unsalted butter',
#    'unsweetened cocoa powder'],
#   'name': 'Chocolate Biscoff Whoopie Pies',
#   'price': 20.94,
#   'serving': 48,
#   'subIngs': {'cream cheese block': {'cream cheese': ['pureed cottage cheese ',
#      'plain yogurt, strained overnight in a cheesecloth']},
#    'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']},
#    'unsweetened cocoa powder': {'baking powder': ['baking soda plus cream of tartar ',
#      ' baking soda plus buttermilk (decrease liquid in recipe by '],
#     'cocoa': ['square unsweetened chocolate']}},
#   'urls': {'source': 'http://www.gimmesomeoven.com/chocolate-biscoff-whoopie-pies/',
#    'img': 'https://spoonacular.com/recipeImages/527691-556x370.jpg'},
#   'usedCount': 4,
#   'usedIngs': ['baking soda', 'egg', 'milk', 'vanilla extract']}}

# %%
import json
with open('testout.json', 'w', encoding='utf-8') as f:
    json.dump(allr.to_json(), f)

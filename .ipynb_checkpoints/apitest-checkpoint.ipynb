# %%
import requests
import pandas as pd
from functools import *
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from backend import recip as rr

# %%
inp = ['baking soda', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar', 'vanilla extract']

# %%
allr = rr.GetRecipies(inp, recnum = 9)
# Out:
# Recipe cache found
# CACHE FOUND - Chocolate Pancakes and Friday Faves
# CACHE FOUND - Snickerdoodle Cream Pies
# CACHE FOUND - Soft & Chewy Peanut Butter Cookies
# CACHE FOUND - Chocolate Greek Yogurt Cupcakes
# CACHE FOUND - Peanut Butter Sheet Cake
# CACHE FOUND - Peanut Butter Blossoms
# CACHE FOUND - Vanilla Cupcakes with Vanilla Buttercream
# CACHE FOUND - Nutella Filled Peanut Butter Criss Crosses
# CACHE FOUND - Chocolate Biscoff Whoopie Pies

# %%
allr.to_json()
# Out:
# {'Blueberry Sourdough Pancakes/with sourdough starter': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 526188,
#   'imglink': 'https://spoonacular.com/recipeImages/526188-312x231.jpg',
#   'missedCount': 0,
#   'missedIngs': [],
#   'name': 'Blueberry Sourdough Pancakes/with sourdough starter',
#   'price': 18.47,
#   'serving': 12,
#   'subIngs': {},
#   'urls': {'source': 'http://cullyskitchen.com/blueberry-sourdough-pancakeswith-sourdough-starter-recipe/',
#    'img': 'https://spoonacular.com/recipeImages/526188-556x370.jpg'},
#   'usedCount': 6,
#   'usedIngs': ['baking soda',
#    'dry yeast',
#    'eggs',
#    'milk',
#    'sourdough starter',
#    'vanilla extract']},
#  'Amish Friendship Bread + Starter': {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 612314,
#   'imglink': 'https://spoonacular.com/recipeImages/612314-312x231.jpg',
#   'missedCount': 3,
#   'missedIngs': ['baking powder', 'chocolate chips', 'cinnamon'],
#   'name': 'Amish Friendship Bread + Starter',
#   'price': 39.04,
#   'serving': 16,
#   'subIngs': {'baking powder': {'baking powder': ['baking soda plus cream of tartar ',
#      ' baking soda plus buttermilk (decrease liquid in recipe by ']},
#    'chocolate chips': {'semisweet chocolate chips': ['chocolate candies ',
#      'peanut butter or other flavored chips',
#      'chopped nuts',
#      'chopped dried fruit']}},
#   'urls': {'source': 'http://www.crazyforcrust.com/2014/09/amish-friendship-bread/',
#    'img': 'https://spoonacular.com/recipeImages/612314-556x370.jpg'},
#   'usedCount': 6,
#   'usedIngs': ['active yeast',
#    'baking soda',
#    'eggs',
#    'milk',
#    'sourdough starter',
#    'vanilla']},
#  'Sourdough Pancakes': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 591445,
#   'imglink': 'https://spoonacular.com/recipeImages/591445-312x231.jpg',
#   'missedCount': 1,
#   'missedIngs': ['bread flour'],
#   'name': 'Sourdough Pancakes',
#   'price': 24.84,
#   'serving': 12,
#   'subIngs': {'bread flour': {'flour  bread': ['all-purpose flour plus wheat gluten ']}},
#   'urls': {'source': 'http://www.completelydelicious.com/2013/05/sourdough-pancakes.html',
#    'img': 'https://spoonacular.com/recipeImages/591445-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['active yeast',
#    'baking soda',
#    'egg',
#    'sourdough starter',
#    'whole milk']},
#  'Yeast Waffle': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 578713,
#   'imglink': 'https://spoonacular.com/recipeImages/578713-312x231.jpg',
#   'missedCount': 1,
#   'missedIngs': ['unsalted butter'],
#   'name': 'Yeast Waffle',
#   'price': 46.16,
#   'serving': 12,
#   'subIngs': {'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://www.foodfanatic.com/recipes/yeast-waffle-recipe/',
#    'img': 'https://spoonacular.com/recipeImages/578713-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['active yeast',
#    'baking soda',
#    'eggs',
#    'vanilla extract',
#    'whole milk']},
#  'Overnight Yeast Waffles: Belgian Batter Up': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 580416,
#   'imglink': 'https://spoonacular.com/recipeImages/580416-312x231.jpg',
#   'missedCount': 1,
#   'missedIngs': ['unsalted butter'],
#   'name': 'Overnight Yeast Waffles: Belgian Batter Up',
#   'price': 46.16,
#   'serving': 12,
#   'subIngs': {'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://www.foodfanatic.com/2013/05/overnight-yeast-waffles-belgian-batter-up/',
#    'img': 'https://spoonacular.com/recipeImages/580416-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['active yeast',
#    'baking soda',
#    'eggs',
#    'vanilla extract',
#    'whole milk']},
#  'Overnight Cinnamon Yeasted Belgian Waffles': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 587367,
#   'imglink': 'https://spoonacular.com/recipeImages/587367-312x231.jpg',
#   'missedCount': 2,
#   'missedIngs': ['ground cinnamon', 'unsalted butter'],
#   'name': 'Overnight Cinnamon Yeasted Belgian Waffles',
#   'price': 45.41,
#   'serving': 6,
#   'subIngs': {'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://www.merrygourmet.com/2012/08/overnight-cinnamon-yeasted-belgian-waffles/',
#    'img': 'https://spoonacular.com/recipeImages/587367-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda', 'eggs', 'milk', 'vanilla extract', 'yeast']},
#  'Monkey Bread Cupcakes': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': ['American'],
#   'id': 535869,
#   'imglink': 'https://spoonacular.com/recipeImages/535869-312x231.jpg',
#   'missedCount': 3,
#   'missedIngs': ['cinnamon', 'sour cream', 'unsalted butter'],
#   'name': 'Monkey Bread Cupcakes',
#   'price': 32.38,
#   'serving': 12,
#   'subIngs': {'sour cream': {'sour cream': ['plain yogurt ',
#      'lemon juice or vinegar plus cream ',
#      'buttermilk mixed with butter']},
#    'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://damndelicious.net/2012/12/05/monkey-bread-cupcakes-christmasweek/',
#    'img': 'https://spoonacular.com/recipeImages/535869-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['active yeast',
#    'baking soda',
#    'egg',
#    'milk',
#    'vanilla extract']},
#  'Overnight Belgian Waffles': {'attrs': {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 749208,
#   'imglink': 'https://spoonacular.com/recipeImages/749208-312x231.jpeg',
#   'missedCount': 3,
#   'missedIngs': ['bananas', 'honey', 'unsalted butter'],
#   'name': 'Overnight Belgian Waffles',
#   'price': 54.48,
#   'serving': 10,
#   'subIngs': {'bananas': {'brandy': ['imitation brandy extract plus water ']},
#    'honey': {'honey': ['white sugar plus water ',
#      'corn syrup',
#      'light treacle syrup']},
#    'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://www.foodnetwork.com/recipes/ina-garten/overnight-belgian-waffles.html',
#    'img': 'https://spoonacular.com/recipeImages/749208-556x370.jpeg'},
#   'usedCount': 5,
#   'usedIngs': ['active yeast',
#    'baking soda',
#    'eggs',
#    'vanilla extract',
#    'whole milk']},
#  "Margot's Sourdough Chocolate Cake": {'attrs': {'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False},
#   'c': True,
#   'cuisines': [],
#   'id': 60771,
#   'imglink': 'https://spoonacular.com/recipeImages/60771-312x231.jpg',
#   'missedCount': 3,
#   'missedIngs': ['ground cinnamon', 'semi-sweet chocolate', 'unsalted butter'],
#   'name': "Margot's Sourdough Chocolate Cake",
#   'price': 105.41,
#   'serving': 5,
#   'subIngs': {'semi-sweet chocolate': {'semisweet chocolate chips': ['chocolate candies ',
#      'peanut butter or other flavored chips',
#      'chopped nuts',
#      'chopped dried fruit']},
#    'unsalted butter': {'butter (salted)': ['margarine ',
#      ' shortening plus salt ',
#      ' vegetable oil plus salt ',
#      ' lard plus salt'],
#     'butter (unsalted)': ['shortening ', ' vegetable oil ', ' lard']}},
#   'urls': {'source': 'http://orangette.blogspot.com/2004/10/like-leaves_03.html',
#    'img': 'https://spoonacular.com/recipeImages/60771-556x370.jpg'},
#   'usedCount': 5,
#   'usedIngs': ['baking soda',
#    'eggs',
#    'milk',
#    'sourdough starter',
#    'vanilla extract']}}

# %%
import json
with open('testout.json', 'w', encoding='utf-8') as f:
    json.dump(allr.to_json(), f)
